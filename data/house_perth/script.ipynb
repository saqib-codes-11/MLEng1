# %%
import pandas as pd

df_base = pd.read_csv('raw.csv', index_col=0)
df_base
# Out:
#                         SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# ADDRESS
# 1 Acorn Place       South Lake  565000         4          2     2.0
# 1 Addis Way              Wandi  365000         3          2     2.0
# ...                        ...     ...       ...        ...     ...
# 9D Shalford Way     Girrawheen  295000         3          1     2.0
# 9E Margaret Street     Midland  295000         3          1     2.0
#
#                     LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ADDRESS
# 1 Acorn Place             600         160      2003.0     18300
# 1 Addis Way               351         139      2013.0     26900
# ...                       ...         ...         ...       ...
# 9D Shalford Way           457          85      1974.0     12600
# 9E Margaret Street        296          95         NaN     16700
#
#                                  NEAREST_STN  NEAREST_STN_DIST  DATE_SOLD  \
# ADDRESS
# ...

# %% [markdown]
# ## ML Simple

# %%
df = df_base.query('SUBURB == "Bertram"')
df
# Out:
#                        SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  \
# ADDRESS
# 1 Datchet Turn        Bertram  270000         3          2     2.0        271
# 1 McKenzie Corner     Bertram  470000         4          2     2.0        646
# ...                       ...     ...       ...        ...     ...        ...
# 93 Centennial Avenue  Bertram  350000         4          2     2.0        585
# 98 Centennial Avenue  Bertram  441000         4          2     2.0        680
#
#                       FLOOR_AREA  BUILD_YEAR  CBD_DIST      NEAREST_STN  \
# ADDRESS
# 1 Datchet Turn               109      2011.0     32000  Kwinana Station
# 1 McKenzie Corner            279      2005.0     33700  Kwinana Station
# ...                          ...         ...       ...              ...
# 93 Centennial Avenue         177      2005.0     33500  Kwinana Station
# 98 Centennial Avenue         195      2004.0     33400  Kwinana Station
#
# ...

# %%
df = df[['PRICE', 'BEDROOMS', 'BATHROOMS', 'GARAGE', 'BUILD_YEAR', 'FLOOR_AREA']].dropna()
df.columns = df.columns.str.title().str.replace('_', ' ')
df
# Out:
#                        Price  Bedrooms  Bathrooms  Garage  Build Year  \
# ADDRESS
# 1 Datchet Turn        270000         3          2     2.0      2011.0
# 1 McKenzie Corner     470000         4          2     2.0      2005.0
# ...                      ...       ...        ...     ...         ...
# 93 Centennial Avenue  350000         4          2     2.0      2005.0
# 98 Centennial Avenue  441000         4          2     2.0      2004.0
#
#                       Floor Area
# ADDRESS
# 1 Datchet Turn               109
# 1 McKenzie Corner            279
# ...                          ...
# 93 Centennial Avenue         177
# 98 Centennial Avenue         195
#
# [204 rows x 6 columns]

# %%
df.to_csv('output/ml_simple.csv')
